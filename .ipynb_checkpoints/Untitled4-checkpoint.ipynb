# %%
from html.parser import HTMLParser
import requests


def _pretty_print(x, preffix=""):
    if isinstance(x, list) or isinstance(x, tuple) or isinstance(x, set):
        return preffix + "[\n" + u",\n".join([_pretty_print(y, preffix + "    ") for y in x]) + "\n" + preffix + "]"
    elif isinstance(x, dict):
        return (preffix + "{\n" + 
                ",\n".join([u"{}: {}".format(
                    _pretty_print(a, preffix + "    "), _pretty_print(b, preffix + "    ").strip()) 
                            for a, b in sorted(x.items())]
                          ) + "\n" + preffix + "}")
    else:
        return preffix + str(x)   

def pretty_print(x):
    print (_pretty_print(x))


class MyParser(HTMLParser):    
    def __init__(self):
        HTMLParser.__init__(self)
        self.result = []
        self.possible_titles = [u"Ученик/Цель", u"Район", u"Формат", u"Ставка"]
        self.myreset()
        
        
    def myreset(self):
        self.cur_title = None
        self.cur_row = {}   
        self.in_orders = False
        self.got_empty_div = 0

        
    def handle_starttag(self, tag, attrs):
        attrs_dict = dict(attrs)
        
        if tag == "table":
            if attrs_dict.get("class") == "order_block ":
                self.in_orders = True
        if self.in_orders:
            if tag == "a":
                if u"Имя" in self.cur_row:
                    self.cur_title = None
                else:
                    self.cur_title = u"Имя"
            if tag == "div":
                self.cur_title = attrs_dict.get("title")
                if not self.cur_title:
                    if self.got_empty_div == 0:
                        self.cur_title = u"Предмет"
                    if self.got_empty_div == 1:
                        self.cur_title = u"Пол преподавателя"
                    self.got_empty_div += 1
                else:
                    if self.cur_title not in self.possible_titles:
                        self.cur_title = None
        if self.cur_title and self.cur_title not in self.cur_row:
            self.cur_row[self.cur_title] = []

            
    def handle_endtag(self, tag):
        if tag == "table" and self.in_orders:
            self.cur_row[u"Имя"] = self.cur_row[u"Имя"][1]
            if u"Пол преподавателя" not in self.cur_row:
                self.cur_row[u"Пол преподавателя"] = u"Любой"
            elif self.cur_row[u"Пол преподавателя"]:
                self.cur_row[u"Пол преподавателя"] = self.cur_row[u"Пол преподавателя"][1]
            else:
                self.cur_row[u"Пол преподавателя"] = u"Любой"
            self.cur_row[u"Предмет"] = self.cur_row[u"Предмет"][0]
            self.result.append(self.cur_row)
            self.myreset()

            
    def handle_data(self, data):
        if self.in_orders:
            if self.cur_title and data.strip():
                if self.cur_title == u"Пол преподавателя":
                    if data.strip() != u"Пол преподавателя =" and not self.cur_row[self.cur_title]:
                        self.cur_title = None
                        return
                self.cur_row[self.cur_title].append(data.strip())

# %%
r = requests.get('https://repetitors.info/backoffice/n.php?all=1', auth=('PavlovVK', 'LllTraZDx3'))

# %%
parser = MyParser()
parser.feed(r.text)
result = parser.result

# %%
pretty_print(result[:5])
# Out:
# [
#     {
#         Имя: Никита,
#         Пол преподавателя: Любой,
#         Предмет: математика,
#         Район: [
#             Сокол,
#             у преподавателя
#         ],
#         Ставка: [
#             1600…2200,
#             руб.,
#             90 мин.
#         ],
#         Ученик/Цель: [
#             студент,
#             Экзамен на сессии
#         ],
#         Формат: [
#             После 16:00
#         ]
#     },
#     {
#         Имя: Анастасия,
#         Пол преподавателя: Любой,
#         Предмет: английский язык,
#         Район: [
#             Апрелевка
#         ],
#         Ставка: [
#             800…1300,
#             руб.,
#             45 мин.
#         ],
#         Ученик/Цель: [
#             дошкольник,
#             Для себя
#         ],
#         Формат: [
#             по дог.,
#         ]
#     },
#     {
#         Имя: Нигина,
#         Пол преподавателя: Любой,
#         Предмет: начальная школа,
#         Район: [
#             Люберцы, (п. Томилино, ул Гоголя, д15),
#             у ученика
#         ],
#         Ставка: [
#             1350…1900,
#             руб.,
#             60 мин.
#         ],
#         Ученик/Цель: [
#             дошкольник,
#             подготовить ребенка к школе
#         ],
#         Формат: [
#             в любое время
#         ]
#     },
#     {
#         Имя: Андрей,
#         Пол преподавателя: Ж,
#         Предмет: английский язык,
#         Район: [
#             Щелково, Фрязино, (Фряновское ш, 64, Щёлково, Московская область),
#             у ученика
#         ],
#         Ставка: [
#             1200,
#             руб.,
#             60 мин.
#         ],
#         Ученик/Цель: [
#             дошкольник,
#             Для работы
#         ],
#         Формат: [
#             по дог.,
#         ]
#     },
#     {
#         Имя: Ангелина Антоновна,
#         Пол преподавателя: Любой,
#         Предмет: строительная механика,
#         Район: [
#             Москва (Скайп),
#             дистанционно
#         ],
#         Ставка: [
#             до 1700,
#             руб.,
#             90 мин.
#         ],
#         Ученик/Цель: [
#             взрослый,
#             Экзамен в вузе
#         ],
#         Формат: [
#             Пн (вечер после 17); Вт (вечер после 17); Ср (вечер после 17); Чт (вечер после 17); Пт (вечер после 17); Сб (вечер после 17); Вс (вечер после 17)
#         ]
#     }
# ]

# %%
def res(cur_str):
    if '…' in cur_str:
        index = cur_str.find('…')
        return cur_str[:index]
    else:
        return cur_str

# %%
import csv

with open('profi_ru.csv', "w", newline="") as file:
    columns = ["Имя", "Предмет", "Пол преподавателя", "Район", "Ставка", "Продолжительность", "Ученик"]
    writer = csv.DictWriter(file, fieldnames=columns)
    writer.writeheader()
    for el in result:
        rate = res(el['Ставка'][0].split(' ')[-1])
        area = el.get('Район', None)
        user = {"Имя": el['Имя'], "Предмет": el['Предмет'], "Пол преподавателя": el['Пол преподавателя'],
            "Район": area[0].split(',')[0] if area else area,
            "Ставка": rate,
            "Продолжительность": el['Ставка'][-1].split(' ')[0], "Ученик": el['Ученик/Цель'][0]
        }
        writer.writerow(user)

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')  # Красивые графики
plt.rcParams['figure.figsize'] = (15, 5)  # Размер картинок

# %%
df = pd.read_csv('profi_ru.csv', sep=',')

# %%
df.head(n = 10)
# Out:
#                   Имя                Предмет Пол преподавателя  \
# 0              Никита             математика             Любой
# 1           Анастасия        английский язык             Любой
# 2              Нигина        начальная школа             Любой
# 3              Андрей        английский язык                 Ж
# 4  Ангелина Антоновна  строительная механика             Любой
# 5            Светлана      высшая математика             Любой
# 6               Архип           русский язык             Любой
# 7             девочка        английский язык             Любой
# 8             Наталья             математика             Любой
# 9               Денис          немецкий язык                 Ж
#
#                   Район  Ставка  Продолжительность  \
# 0                 Сокол    1600                 90
# 1             Апрелевка     800                 45
# 2               Люберцы    1350                 60
# 3               Щелково    1200                 60
# 4        Москва (Скайп)    1700                 90
# 5  Проспект Вернадского    2300                 90
# 6          Авиамоторная    1000                 60
# 7       Севастопольская    2000                 90
# 8            Новокосино     800                 60
# 9           Сходненская    1900                 90
#
#                             Ученик
# 0                          студент
# 1                       дошкольник
# 2                       дошкольник
# 3                       дошкольник
# 4                         взрослый
# 5                          студент
# 6                         взрослый
# 7  4 кл., учится в Доме Станкевича
# 8                            9 кл.
# 9                         взрослый

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
# Имя                  2000 non-null object
# Предмет              2000 non-null object
# Пол преподавателя    2000 non-null object
# Район                2000 non-null object
# Ставка               2000 non-null int64
# Продолжительность    2000 non-null int64
# Ученик               2000 non-null object
# dtypes: int64(2), object(5)
# memory usage: 109.5+ KB

# %%
plt.rcParams['figure.figsize'] = (15, 7)  # Размер картинок

# %%
df['Предмет'].value_counts()[:30].plot(kind='barh');
plt.legend()
plt.title('Популярные предметы');

# %%
df['Район'].value_counts()[1:50].plot(kind='bar');
plt.legend()
plt.title('Районы');

# %%
df.head()
# Out:
#                   Имя                Предмет Пол преподавателя  \
# 0              Никита             математика             Любой
# 1           Анастасия        английский язык             Любой
# 2              Нигина        начальная школа             Любой
# 3              Андрей        английский язык                 Ж
# 4  Ангелина Антоновна  строительная механика             Любой
#
#             Район  Ставка  Продолжительность      Ученик
# 0           Сокол    1600                 90     студент
# 1       Апрелевка     800                 45  дошкольник
# 2         Люберцы    1350                 60  дошкольник
# 3         Щелково    1200                 60  дошкольник
# 4  Москва (Скайп)    1700                 90    взрослый

# %%
df[df['Продолжительность'] == 60].groupby('Предмет')['Ставка'].mean().sort_values(ascending=False)[1:50].plot(kind='bar')

plt.legend()
plt.title('Цена за 60 минут');

# %%
df[df['Продолжительность'] == 90].groupby('Предмет')['Ставка'].mean().sort_values(ascending=False)[1:50].plot(kind='bar')

plt.legend()
plt.title('Цена за 90 минут');

# %%
df.head()
# Out:
#                   Имя                Предмет Пол преподавателя  \
# 0              Никита             математика             Любой
# 1           Анастасия        английский язык             Любой
# 2              Нигина        начальная школа             Любой
# 3              Андрей        английский язык                 Ж
# 4  Ангелина Антоновна  строительная механика             Любой
#
#             Район  Ставка  Продолжительность      Ученик
# 0           Сокол    1600                 90     студент
# 1       Апрелевка     800                 45  дошкольник
# 2         Люберцы    1350                 60  дошкольник
# 3         Щелково    1200                 60  дошкольник
# 4  Москва (Скайп)    1700                 90    взрослый

# %%
df['Пол преподавателя'].value_counts().plot(kind='bar')
plt.legend()
plt.title('Предпочитаемый пол');

# %%
df['Ученик'].value_counts()[:30].plot(kind='bar')
plt.legend()
plt.title('Ученик');

# %%
df['Продолжительность'].value_counts().plot(kind='bar')
plt.legend()
plt.title('Продолжительность занятия');
